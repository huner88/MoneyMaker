# %%
import pandas as pd
from fredapi import Fred
import numpy as np 
from matplotlib import pyplot as plt 
from matplotlib.pyplot import figure
import bt# step 1: build Investment Clock Class
from tiingo import TiingoClient
# %matplotlib inline

# %%
def AssetPoolFixed():
    return {
      "Reflection": ['IYF','IYH','IYK','IYC'],
      "Recovery": ['IYZ','IYW','IYM','IYC'],
      "Overheat": ['IYJ','IYW','IYM','IYE'],
      "Stagflation": ['IDU','IYH','IYK','IYE']
    }

# %%
fred = Fred(api_key="f47911535ed5029402710ad27afa0d23")
signals = pd.DataFrame(dict(
    GDP = fred.get_series('GDPC1'),# Real GDP
    CPI = fred.get_series('CPILFESL'), # Core CPI
  )
).fillna(method='ffill').pct_change(12).dropna()*100

print(signals)
print("average of GDP")
print(signals['GDP'].mean())
print('average of CPI')
print(signals['CPI'].mean())
# Out:
#                  GDP       CPI
# 1958-01-01 -2.871428  2.807018
# 1958-02-01 -2.871428  2.797203
# 1958-03-01 -2.871428  2.787456
# 1958-04-01 -2.018409  2.430556
# 1958-05-01 -2.018409  2.430556
# ...              ...       ...
# 2021-10-01  5.533484  4.593958
# 2021-11-01  5.533484  4.952634
# 2021-12-01  5.533484  5.476621
# 2022-01-01  3.939172  6.040783
# 2022-02-01  3.939172  6.415744
#
# [770 rows x 2 columns]
# average of GDP
# 2.99776107412402
# average of CPI
# 3.6305661963321576

# %%
plt.title("Matplotlib demo") 
# plt.xlabel("x axis caption") 
# plt.ylabel("y axis caption") 
y1 = signals['GDP']
y2 = signals['CPI']
x1 = signals.index
x2 = signals.index
plt.plot(x1,y1,x2,y2)
plt.legend(labels=['GDP','CPI'],loc='best')
plt.show()
plt.rcParams['figure.figsize'] = [20, 5]

# %%
def InvestmentClockFixed(x,cuts={'GDP':2.9,'CPI':3}):
   
    x_ = x.copy().assign(Growth=None,Inflation=None,Theme=None)

    # define high and low growth
    x_.loc[x['GDP']<=cuts["GDP"],'Growth'] = 'low'
    x_.loc[x['GDP']>cuts['GDP'],'Growth'] = 'high'

    # define high and low inflation  
    x_.loc[x['CPI']<=cuts['CPI'],'Inflation'] = 'low'
    x_.loc[x['CPI']>cuts['CPI'],'Inflation'] = 'high'

    # define investment clock phases
    x_.loc[(x_.Growth=='low')&(x_.Inflation=='low'),'Theme'] = 'Reflection'
    x_.loc[(x_.Growth=='high')&(x_.Inflation=='low'),'Theme'] = 'Recovery'
    x_.loc[(x_.Growth=='high')&(x_.Inflation=='high'),'Theme'] = 'Overheat'
    x_.loc[(x_.Growth=='low')&(x_.Inflation=='high'),'Theme'] = 'Stagflation'
    return x_.dropna()

# %%
themes = InvestmentClockFixed(signals,cuts={'GDP':2.5,'CPI':2})
print(themes.head(10))
fig = plt.figure(figsize=(12,8))
fig.suptitle(' gInvestment Clock Themes with Fixed Cuts',fontsize=16)
ax1 = fig.add_axes((0,0.5,1,0.45))
ax2 = fig.add_axes((0,0,0.3,0.4))
ax3 = fig.add_axes((0.35,0,0.3,0.4))
ax4 = fig.add_axes((0.7,0,0.3,0.4))
y_lim = (-10,15)
colors = dict(
  Overheat='#f4d19e',
  Recovery='#87ca9d',
  Reflection='#dbdbdb',
  Stagflation='#ffb3ba'
) 
p1 = themes[['GDP','CPI']].plot(ax=ax1)
for t in ['Overheat','Recovery','Reflection','Stagflation']:
       ax1.fill_between(
      themes.index, y_lim[0],y_lim[1], 
      where=(themes.Theme==t),
      interpolate = True,
      facecolor=colors[t], 
      alpha = 0.5
   )
growth_counts=themes.Growth.value_counts()
ax2.pie(growth_counts,autopct='%.1f %%',
        labels=growth_counts.index)
ax2.set_title(' gGrowth')
inflation_counts=themes.Inflation.value_counts()
ax3.pie(inflation_counts,autopct='%.1f %%',
        labels=inflation_counts.index)
ax3.set_title(' gInflation')
theme_counts=themes.Theme.value_counts().sort_index(ascending=True)
ax4.pie(theme_counts,autopct='%.1f %%',
        labels=theme_counts.index,colors=colors.values())
ax4.set_title(' gTheme')
plt.show()
# Out:
#                  GDP       CPI Growth Inflation        Theme
# 1958-01-01 -2.871428  2.807018    low      high  Stagflation
# 1958-02-01 -2.871428  2.797203    low      high  Stagflation
# 1958-03-01 -2.871428  2.787456    low      high  Stagflation
# 1958-04-01 -2.018409  2.430556    low      high  Stagflation
# 1958-05-01 -2.018409  2.430556    low      high  Stagflation
# 1958-06-01 -2.018409  2.422145    low      high  Stagflation
# 1958-07-01 -0.724798  2.068966    low      high  Stagflation
# 1958-08-01 -0.724798  2.068966    low      high  Stagflation
# 1958-09-01 -0.724798  2.061856    low      high  Stagflation
# 1958-10-01  2.658137  1.712329   high       low     Recovery

# %%
symbols = ['IYC','IDU','IYZ','IYW','IYJ','IYH','IYF','IYE','IYK','IYM','IYR']
noa = len(symbols)

config = {}
#client = TiingoClient()
config['session'] = False
config['api_key'] = "d32a305664615d26bbd98905ab7d4b801e70b713"
client = TiingoClient(config)
dataUncut = pd.DataFrame()
dataUncut = client.get_dataframe(symbols,
                                      frequency='daily',
                                      metric_name='adjClose',
                                      startDate = '2002-07-29',
                                      endDate='2021-08-19')
print(dataUncut)
# Out:
#                                  IYC        IDU        IYZ         IYW  \
# 2002-07-29 00:00:00+00:00   9.431615  12.545165   9.084387    7.225539
# 2002-07-30 00:00:00+00:00   9.421006  13.465497   9.302223    7.280129
# 2002-07-31 00:00:00+00:00   9.308548  13.587501   9.626035    7.140379
# 2002-08-01 00:00:00+00:00   9.039073  13.314319   9.390536    6.791002
# 2002-08-02 00:00:00+00:00   8.699578  13.088877   9.337548    6.581376
# ...                              ...        ...        ...         ...
# 2021-08-13 00:00:00+00:00  78.324174  83.151732  33.432473  104.633771
# 2021-08-16 00:00:00+00:00  78.395450  83.661448  33.334142  104.763503
# 2021-08-17 00:00:00+00:00  77.317334  83.701821  33.176813  103.675751
# 2021-08-18 00:00:00+00:00  77.117960  83.230316  32.793322  102.458267
# 2021-08-19 00:00:00+00:00  77.098022  83.475891  33.098148  103.276575
#
#                                   IYJ         IYH        IYF        IYE  \
# 2002-07-29 00:00:00+00:00   15.355110   36.853720  24.301524   8.531252
# 2002-07-30 00:00:00+00:00   15.504374   37.209571  24.495797   8.443412
# 2002-07-31 00:00:00+00:00   15.481410   38.161084  24.752516   8.644802
# 2002-08-01 00:00:00+00:00   15.175227   36.938815  24.225202   8.092049
# 2002-08-02 00:00:00+00:00   14.658542   36.853720  23.520961   8.055627
# ...                               ...         ...        ...        ...
# 2021-08-13 00:00:00+00:00  113.373877  286.529980  83.797787  25.977855
# 2021-08-16 00:00:00+00:00  113.731523  289.257893  83.787902  25.501465
# 2021-08-17 00:00:00+00:00  112.638715  292.670263  83.254095  25.326464
# 2021-08-18 00:00:00+00:00  111.575711  288.166728  82.314991  24.791740
# 2021-08-19 00:00:00+00:00  111.009437  288.791668  81.959119  24.120905
#
#                                   IYK         IYM         IYR
# 2002-07-29 00:00:00+00:00   28.767441   26.520058   18.203454
# 2002-07-30 00:00:00+00:00   28.299569   25.472195   18.482820
# 2002-07-31 00:00:00+00:00   28.840963   25.598783   18.569982
# 2002-08-01 00:00:00+00:00   28.687234   25.577685   18.312966
# 2002-08-02 00:00:00+00:00   28.607027   24.410268   17.910679
# ...                               ...         ...         ...
# 2021-08-13 00:00:00+00:00  185.724341  134.274548  105.240436
# 2021-08-16 00:00:00+00:00  184.787833  133.306412  105.102802
# 2021-08-17 00:00:00+00:00  182.638104  131.330624  105.112633
# 2021-08-18 00:00:00+00:00  181.840297  129.700599  104.090213
# 2021-08-19 00:00:00+00:00  181.416404  127.774206  104.660409
#
# [4800 rows x 11 columns]

# %%
dataUncut

dataUncut.to_csv('ishareETF_data_2002.csv')

# %%
symbols = ['IVV']
noa = len(symbols)

config = {}
#client = TiingoClient()
config['session'] = False
config['api_key'] = "d32a305664615d26bbd98905ab7d4b801e70b713"
client = TiingoClient(config)
dataIVV = pd.DataFrame()
dataIVV = client.get_dataframe(symbols,
                                      frequency='daily',
                                      metric_name='adjClose',
                                      startDate = '2002-07-29',
                                      endDate='2021-08-19')
print(dataIVV)
# Out:
#                                   IVV
# 2002-07-29 00:00:00+00:00   61.084220
# 2002-07-30 00:00:00+00:00   61.970289
# 2002-07-31 00:00:00+00:00   62.249741
# 2002-08-01 00:00:00+00:00   60.320837
# 2002-08-02 00:00:00+00:00   58.984918
# ...                               ...
# 2021-08-13 00:00:00+00:00  443.277430
# 2021-08-16 00:00:00+00:00  444.415688
# 2021-08-17 00:00:00+00:00  441.396829
# 2021-08-18 00:00:00+00:00  436.635939
# 2021-08-19 00:00:00+00:00  437.279303
#
# [4800 rows x 1 columns]

# %%
#pricesData = pd.read_csv('ishareETF_data.csv')
dataUncut.index = pd.to_datetime(dataUncut.index).strftime('%Y/%m/%d')
dataUncut.index = pd.to_datetime(dataUncut.index)
print(dataUncut.head(10))
prices = dataUncut.dropna()
# Out:
#                  IYC        IDU       IYZ       IYW        IYJ        IYH  \
# 2002-07-29  9.431615  12.545165  9.084387  7.225539  15.355110  36.853720
# 2002-07-30  9.421006  13.465497  9.302223  7.280129  15.504374  37.209571
# 2002-07-31  9.308548  13.587501  9.626035  7.140379  15.481410  38.161084
# 2002-08-01  9.039073  13.314319  9.390536  6.791002  15.175227  36.938815
# 2002-08-02  8.699578  13.088877  9.337548  6.581376  14.658542  36.853720
# 2002-08-05  8.391910  12.897915  8.931312  6.397954  14.122720  35.275601
# 2002-08-06  8.657141  13.359407  8.948974  6.662170  14.957071  36.010510
# 2002-08-07  8.816279  13.510586  8.972524  6.791002  15.037444  37.317873
# 2002-08-08  8.943590  13.568935  9.325773  7.105441  15.424001  38.632972
# 2002-08-09  8.932981  13.648503  9.343436  6.976608  15.424001  38.447311
#
#                   IYF       IYE        IYK        IYM        IYR
# 2002-07-29  24.301524  8.531252  28.767441  26.520058  18.203454
# 2002-07-30  24.495797  8.443412  28.299569  25.472195  18.482820
# 2002-07-31  24.752516  8.644802  28.840963  25.598783  18.569982
# 2002-08-01  24.225202  8.092049  28.687234  25.577685  18.312966
# 2002-08-02  23.520961  8.055627  28.607027  24.410268  17.910679
# 2002-08-05  22.740398  7.669986  28.272833  23.601515  17.602260
# 2002-08-06  23.677074  8.019206  28.219362  24.564986  17.646958
# 2002-08-07  23.864409  8.100619  28.673866  25.120564  18.013486
# 2002-08-08  24.891282  8.477691  29.375674  25.640978  18.017956
# 2002-08-09  25.057803  8.608381  29.442513  25.851957  17.792228

# %%
dataIVV
dataIVV.to_csv('ishareETF_IVV_data_2002.csv')

# %%
dataIVV.index = pd.to_datetime(dataIVV.index).strftime('%Y/%m/%d')
dataIVV.index = pd.to_datetime(dataIVV.index)
print(dataIVV.head(10))
# Out:
#                   IVV
# 2002-07-29  61.084220
# 2002-07-30  61.970289
# 2002-07-31  62.249741
# 2002-08-01  60.320837
# 2002-08-02  58.984918
# 2002-08-05  57.062831
# 2002-08-06  58.773625
# 2002-08-07  59.932330
# 2002-08-08  61.936209
# 2002-08-09  62.195214

# %%
import bt# step 1: build Investment Clock Class
class InvestmentClock(bt.Algo):   
    def __init__(self, themes,lag = pd.DateOffset(days=0),pool = AssetPoolFixed()):
        super(InvestmentClock, self).__init__()
        self.Themes = themes
        self.lag = lag
        self.pool = pool   
    def __call__(self, target):
        t0 = target.now - self.lag
        Theme = self.Themes[:t0][-1]
        target.temp['selected'] = self.pool[Theme]
        return True# step 2: build Investment Clock backtest
def bt_InvestmentClock(name,tickers,prices,signals,cuts={'GDP':2.5,'CPI':2}):

    themes = InvestmentClockFixed(signals,cuts)
    print('themes:')
    print(themes)
    asset_pool = AssetPoolFixed()
    print("asset_pool:")
    print(asset_pool)
    
    s = bt.Strategy(name,algos = [bt.algos.RunQuarterly(),bt.algos.SelectAll(),bt.algos.SelectThese(tickers),
          InvestmentClock(themes.Theme,
             lag=pd.DateOffset(days=0),
             pool = asset_pool ),
          bt.algos.WeighEqually(),
          bt.algos.Rebalance()
        ],
       )
    print('themes.Theme')
    print(themes.Theme)
    return bt.Backtest(s, prices)

# %%
def bt_passive(name,tickers,prices):
    s = bt.Strategy(name,
         algos = [
            bt.algos.RunQuarterly(),
            bt.algos.SelectAll(),
            bt.algos.SelectThese(tickers),
            bt.algos.WeighEqually(),
            bt.algos.Rebalance()
         ],
    )
    return bt.Backtest(s, prices)

# %%
tickers = ['IYC','IDU','IYZ','IYW','IYJ','IYH','IYF','IYE','IYK','IYM','IYR']
prices2 = dataIVV
backtest_sp50= bt_passive('SP50',['IVV'],prices2)
backtest_spew = bt_passive('SPEW',tickers,prices)
prices = dataUncut.dropna()
backtest_spic = bt_InvestmentClock('SPIC',tickers,prices,signals,cuts={'GDP':2.5,'CPI':2})
report = bt.run(backtest_sp50, backtest_spew,backtest_spic)
# create a backtest and run it
report.plot()
report.display()
# Out:
# themes:
#                  GDP       CPI Growth Inflation        Theme
# 1958-01-01 -2.871428  2.807018    low      high  Stagflation
# 1958-02-01 -2.871428  2.797203    low      high  Stagflation
# 1958-03-01 -2.871428  2.787456    low      high  Stagflation
# 1958-04-01 -2.018409  2.430556    low      high  Stagflation
# 1958-05-01 -2.018409  2.430556    low      high  Stagflation
# ...              ...       ...    ...       ...          ...
# 2021-10-01  5.533484  4.593958   high      high     Overheat
# 2021-11-01  5.533484  4.952634   high      high     Overheat
# 2021-12-01  5.533484  5.476621   high      high     Overheat
# 2022-01-01  3.939172  6.040783   high      high     Overheat
# 2022-02-01  3.939172  6.415744   high      high     Overheat
#
# [770 rows x 5 columns]
# asset_pool:
# {'Reflection': ['IYF', 'IYH', 'IYK', 'IYC'], 'Recovery': ['IYZ', 'IYW', 'IYM', 'IYC'], 'Overheat': ['IYJ', 'IYW', 'IYM', 'IYE'], 'Stagflation': ['IDU', 'IYH', 'IYK', 'IYE']}
# themes.Theme
# 1958-01-01    Stagflation
# 1958-02-01    Stagflation
# 1958-03-01    Stagflation
# 1958-04-01    Stagflation
# 1958-05-01    Stagflation
#                  ...
# 2021-10-01       Overheat
# 2021-11-01       Overheat
# 2021-12-01       Overheat
# 2022-01-01       Overheat
# 2022-02-01       Overheat
# Name: Theme, Length: 770, dtype: object
# Stat                 SP50        SPEW        SPIC
# -------------------  ----------  ----------  ----------
# Start                2002-07-28  2002-07-28  2002-07-28
# End                  2021-08-19  2021-08-19  2021-08-19
# Risk-free rate       0.00%       0.00%       0.00%
#
# Total Return         615.83%     565.30%     839.86%
# Daily Sharpe         0.64        0.62        0.73
# Daily Sortino        0.99        0.95        1.14
# CAGR                 10.88%      10.45%      12.47%
# Max Drawdown         -55.25%     -55.02%     -47.49%
# Calmar Ratio         0.20        0.19        0.26
#
# MTD                  0.32%       -0.51%      -2.46%
# 3m                   7.42%       4.08%       0.63%
# 6m                   13.55%      11.21%      6.66%
# YTD                  18.42%      17.36%      10.88%
# 1Y                   32.48%      31.94%      27.07%
# 3Y (ann.)            17.64%      13.23%      12.51%
# 5Y (ann.)            17.24%      12.68%      11.71%
# 10Y (ann.)           16.92%      13.71%      14.79%
# Since Incep. (ann.)  10.88%      10.45%      12.47%
#
# Daily Sharpe         0.64        0.62        0.73
# Daily Sortino        0.99        0.95        1.14
# Daily Mean (ann.)    12.17%      11.80%      13.49%
# Daily Vol (ann.)     19.10%      19.16%      18.57%
# Daily Skew           -0.24       -0.35       -0.20
# Daily Kurt           12.19       12.78       12.94
# Best Day             11.10%      10.96%      12.83%
# Worst Day            -11.57%     -11.62%     -10.50%
#
# Monthly Sharpe       0.79        0.74        0.88
# Monthly Sortino      1.31        1.21        1.54
# Monthly Mean (ann.)  11.30%      10.99%      12.65%
# Monthly Vol (ann.)   14.37%      14.76%      14.32%
# Monthly Skew         -0.67       -0.79       -0.54
# Monthly Kurt         1.84        3.04        1.52
# Best Month           12.68%      13.17%      12.12%
# Worst Month          -16.63%     -19.14%     -14.37%
#
# Yearly Sharpe        0.78        0.76        0.93
# Yearly Sortino       1.44        1.39        2.10
# Yearly Mean          12.22%      11.70%      13.49%
# Yearly Vol           15.74%      15.42%      14.51%
# Yearly Skew          -1.65       -1.74       -1.06
# Yearly Kurt          4.51        4.63        2.79
# Best Year            32.30%      30.97%      38.29%
# Worst Year           -37.02%     -36.68%     -27.97%
#
# Avg. Drawdown        -1.74%      -1.95%      -2.19%
# Avg. Drawdown Days   21.90       22.09       23.00
# Avg. Up Month        3.05%       3.07%       3.23%
# Avg. Down Month      -3.65%      -3.68%      -3.33%
# Win Year %           89.47%      84.21%      89.47%
# Win 12m %            87.21%      84.47%      88.13%

# %%
# Plot Sector Weights
report.backtests['SPIC'].security_weights.plot.area()
report.plot_security_weights(1)
plt.title("Security Weights for S&P Sector Rotator Strategy")
plt.legend(ncol=2,loc='right',bbox_to_anchor=(1.2,0.5))
plt.show()

# %%
reportData = report.backtests['SPIC'].security_weights
reportData.to_csv('reportData.csv')
plotData = reportData.iloc[[-10]].T
plotData.columns = ['name']
plot = plotData.plot.pie(y='name', title="Title", legend=False, \
                   autopct='%1.1f%%',  \
                   shadow=True, startangle=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5259f398f0ec> in <module>
# ----> 1 reportData = report.backtests['SPIC'].security_weights
#       2 reportData.to_csv('reportData.csv')
#       3 plotData = reportData.iloc[[-10]].T
#       4 plotData.columns = ['name']
#       5 plot = plotData.plot.pie(y='name', title="Title", legend=False, \
#
# NameError: name 'report' is not defined

# %%
reportData.value_counts()
reportData.mask(reportData > 0, 1, inplace=True)
print(reportData)
print(reportData.sum(axis=0)/len(reportData))

drawData = reportData.sum(axis=0)/len(reportData)
plot =drawData.plot.pie(y='name', title="Title", legend=False, \
                   autopct='%1.1f%%',  \
                   shadow=True, startangle=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0a7a9ca0d7c4> in <module>
# ----> 1 reportData.value_counts()
#       2 reportData.mask(reportData > 0, 1, inplace=True)
#       3 print(reportData)
#       4 print(reportData.sum(axis=0)/len(reportData))
#       5
#
# NameError: name 'reportData' is not defined
